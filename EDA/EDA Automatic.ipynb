# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt, seaborn as sns,scipy as sp,warnings
warnings.filterwarnings('ignore')
df = pd.read_csv(r'C:\Users\ADMIN\Documents\Data_Science\Data\Titanic.csv')

# %% [markdown]
# 1. AUTOVIZ

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df = AV.AutoViz(r'C:\Users\ADMIN\Documents\Data_Science\Data\Titanic.csv')

# %% [markdown]
# 2. DTALE

# %%
import dtale
dtale.show(df)

# %% [markdown]
# 3. PANDAS PROFILING

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df,explorative=True)
profile.to_file(r'C:\Users\ADMIN\Desktop\Data Storytelling\Titanic_profilung.html')

# %% [markdown]
# 4. SWEETVIZ

# %%
import sweetviz as sv
report = sv.analyze(df)
report.show_html(r'C:\Users\ADMIN\Desktop\Data Storytelling\Titanic_Sweetviz.html')

# %% [markdown]
# 5. PANDAS VISUAL ANALYSIS (df must have to under import lux)

# %%
from pandas_visual_analysis import VisualAnalysis
VisualAnalysis(df)

# %% [markdown]
# 6. LUX

# %%
import lux
## import file in github
# df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
df = pd.read_csv(r'C:\Users\ADMIN\Documents\Data_Science\Data\Titanic.csv')

# %% [markdown]
# 7. DATAPREP

# %%
from dataprep.eda import create_report
create_report(df)

# %% [markdown]
# 8. KLIB

# %%
import klib
klib.cat_plot(df)
# klib.corr_mat(df)
# klib.corr_plot(df)
klib.dist_plot(df)
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)
